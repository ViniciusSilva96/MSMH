# %% [markdown]
# <a href="https://colab.research.google.com/github/ViniciusSilva96/MSMH/blob/main/Aula%202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy.random import default_rng

# %%
rng = default_rng()
vals = rng.standard_normal(1000)
more_vals = rng.standard_normal(1000)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(24, 8))
ax1.hist(vals, 20, density=True, facecolor='b');
ax2.hist(more_vals, 20, density=True, facecolor='r');
